# %% [markdown]
# <a href="https://colab.research.google.com/github/bttrung/CVND-udacity-facebook-scholarship/blob/master/images-processing/1_Images_as_numerical_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.image as mpimg  # for reading in images

import matplotlib.pyplot as plt
import cv2  # computer vision library

# %matplotlib inline

# %%
image = mpimg.imread('dog-img.jpeg')
image.shape
# Out:
# (381, 678, 3)

# %%
image
# Out:
# array([[[156, 165, 172],
#         [156, 165, 172],
#         [156, 165, 172],
#         ...,
#         [ 62,  55,   9],
#         [ 61,  54,   8],
#         [ 61,  54,   8]],
#
#        [[153, 162, 167],
#         [153, 162, 167],
#         [153, 162, 167],
#         ...,
#         [ 62,  55,   9],
#         [ 61,  54,   8],
#         [ 61,  54,   8]],
#
#        [[150, 159, 164],
#         [150, 159, 164],
#         [150, 159, 164],
#         ...,
#         [ 61,  54,   8],
#         [ 60,  53,   7],
#         [ 60,  53,   7]],
#
#        ...,
#
#        [[105,  94,  38],
#         [107,  96,  42],
#         [112, 101,  47],
#         ...,
#         [131, 123,  58],
#         [129, 121,  56],
#         [128, 120,  55]],
#
#        [[104,  95,  38],
#         [107,  98,  43],
#         [113, 104,  49],
#         ...,
#         [128, 120,  55],
#         [126, 118,  53],
#         [125, 117,  52]],
#
#        [[106,  97,  40],
#         [110, 101,  46],
#         [116, 107,  52],
# ...

# %%
plt.imshow(image)

# %%
gray_img = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
gray_img.shape
# Out:
# (381, 678)

# %%
gray_img
# Out:
# array([[163, 163, 163, ...,  52,  51,  51],
#        [160, 160, 160, ...,  52,  51,  51],
#        [157, 157, 157, ...,  51,  50,  50],
#        ...,
#        [ 91,  93,  98, ..., 118, 116, 115],
#        [ 91,  94, 100, ..., 115, 113, 112],
#        [ 93,  97, 103, ..., 113, 111, 110]], dtype=uint8)

# %%
plt.imshow(gray_img, cmap='gray')

# %%
x = 400
y = 300

print(gray_img[y,x])
# Out:
# 167

# %%
max_val = np.amax(gray_img)
min_val = np.amin(gray_img)

print('Max: ', max_val)
print('Min: ', min_val)
# Out:
# Max:  252
# Min:  1

# %%
# Create a 5x5 image using just grayscale, numerical values
tiny_image = np.array([[0, 20, 30, 150, 120],
                      [200, 200, 250, 70, 3],
                      [50, 180, 85, 40, 90],
                      [240, 100, 50, 255, 10],
                      [30, 0, 75, 190, 220]])

# To show the pixel grid, use matshow
plt.matshow(tiny_image, cmap='gray')

## TODO: See if you can draw a tiny smiley face or something else!
## You can change the values in the array above to do this
