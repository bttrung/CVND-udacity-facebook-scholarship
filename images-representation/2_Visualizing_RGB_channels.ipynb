# %% [markdown]
# <a href="https://colab.research.google.com/github/bttrung/CVND-udacity-facebook-scholarship/blob/master/images-processing/2_Visualizing_RGB_channels.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
image = mpimg.imread('tiger.jpg')
plt.imshow(image)

# %%
image.shape
# Out:
# (885, 1400, 3)

# %%
image
# Out:
# array([[[ 67,  73,  47],
#         [ 68,  74,  48],
#         [ 69,  75,  49],
#         ...,
#         [ 83,  97,  48],
#         [ 81,  95,  46],
#         [ 75,  89,  40]],
#
#        [[ 66,  72,  46],
#         [ 67,  73,  47],
#         [ 69,  75,  49],
#         ...,
#         [ 82,  96,  47],
#         [ 82,  96,  47],
#         [ 79,  93,  44]],
#
#        [[ 66,  72,  46],
#         [ 66,  72,  46],
#         [ 68,  74,  48],
#         ...,
#         [ 78,  92,  43],
#         [ 80,  94,  45],
#         [ 79,  93,  44]],
#
#        ...,
#
#        [[ 46,  72,  33],
#         [ 46,  72,  33],
#         [ 47,  73,  34],
#         ...,
#         [185, 110,  45],
#         [191, 116,  51],
#         [197, 122,  57]],
#
#        [[ 46,  72,  33],
#         [ 47,  73,  34],
#         [ 47,  73,  34],
#         ...,
#         [187, 112,  47],
#         [196, 121,  56],
#         [202, 127,  62]],
#
#        [[ 47,  73,  34],
#         [ 47,  73,  34],
#         [ 47,  73,  34],
# ...

# %%
# Isolate RGB channels
r = image[:,:,0]
g = image[:,:,1]
b = image[:,:,2]

# Visualize the individual color channels
f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20,10))
ax1.set_title('R channel')
ax1.imshow(r, cmap='gray')
ax2.set_title('G channel')
ax2.imshow(g, cmap='gray')
ax3.set_title('B channel')
ax3.imshow(b, cmap='gray')

## Which area has the lowest value for red? What about for blue?

# %%
r
# Out:
# array([[ 67,  68,  69, ...,  83,  81,  75],
#        [ 66,  67,  69, ...,  82,  82,  79],
#        [ 66,  66,  68, ...,  78,  80,  79],
#        ...,
#        [ 46,  46,  47, ..., 185, 191, 197],
#        [ 46,  47,  47, ..., 187, 196, 202],
#        [ 47,  47,  47, ..., 187, 198, 205]], dtype=uint8)

# %%
g
# Out:
# array([[ 73,  74,  75, ...,  97,  95,  89],
#        [ 72,  73,  75, ...,  96,  96,  93],
#        [ 72,  72,  74, ...,  92,  94,  93],
#        ...,
#        [ 72,  72,  73, ..., 110, 116, 122],
#        [ 72,  73,  73, ..., 112, 121, 127],
#        [ 73,  73,  73, ..., 112, 123, 130]], dtype=uint8)

# %%
b
# Out:
# array([[47, 48, 49, ..., 48, 46, 40],
#        [46, 47, 49, ..., 47, 47, 44],
#        [46, 46, 48, ..., 43, 45, 44],
#        ...,
#        [33, 33, 34, ..., 45, 51, 57],
#        [33, 34, 34, ..., 47, 56, 62],
#        [34, 34, 34, ..., 47, 58, 65]], dtype=uint8)

# %%
ax2.imshow(g)
